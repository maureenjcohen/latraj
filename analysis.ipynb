# %% [markdown]
# # Venus Trajectory Simulations

# %% [markdown]
# ## Working notebook

# %%
import importlib
import config
import custom_kernels
import heatmap
import traj_stats
import parcels
importlib.reload(config)
importlib.reload(custom_kernels)
importlib.reload(heatmap)
importlib.reload(traj_stats)
# Out:
# <module 'traj_stats' from '/home/tpj37/latraj/traj_stats.py'>

# %%
# %run run_venus_simulation.py
# Out:
# ['inputs//XinsTest.nc']
# INFO: Output files are stored in outputs/Test2.zarr.
#   0%|                                                                                    | 0/5184000.0 [00:00<?, ?it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#   6%|███▋                                                              | 288300.0/5184000.0 [00:05<01:53, 43226.79it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  11%|███████▏                                                          | 568800.0/5184000.0 [00:10<01:43, 44474.44it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  16%|██████████▋                                                       | 844200.0/5184000.0 [00:17<01:52, 38732.56it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  22%|██████████████▏                                                  | 1126800.0/5184000.0 [00:24<01:42, 39753.52it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  27%|█████████████████▌                                               | 1402500.0/5184000.0 [00:32<02:07, 29653.52it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  32%|█████████████████████▏                                           | 1684800.0/5184000.0 [00:42<02:10, 26910.11it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  38%|████████████████████████▌                                        | 1962000.0/5184000.0 [00:53<02:08, 25025.43it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  43%|████████████████████████████▏                                    | 2246400.0/5184000.0 [01:07<01:58, 24745.84it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  49%|███████████████████████████████▌                                 | 2522100.0/5184000.0 [01:19<02:31, 17625.89it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  54%|███████████████████████████████████▏                             | 2802600.0/5184000.0 [01:32<02:03, 19263.64it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  59%|██████████████████████████████████████▋                          | 3081600.0/5184000.0 [01:46<01:45, 19953.90it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  65%|██████████████████████████████████████████▏                      | 3362400.0/5184000.0 [02:01<01:42, 17821.84it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  70%|█████████████████████████████████████████████▋                   | 3641700.0/5184000.0 [02:17<01:44, 14769.06it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  76%|█████████████████████████████████████████████████▏               | 3920700.0/5184000.0 [02:33<01:35, 13190.62it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  81%|████████████████████████████████████████████████████▋            | 4201500.0/5184000.0 [02:52<01:16, 12892.68it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  86%|████████████████████████████████████████████████████████▏        | 4480500.0/5184000.0 [03:12<00:57, 12333.25it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  92%|███████████████████████████████████████████████████████████▋     | 4761300.0/5184000.0 [03:32<00:41, 10121.95it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
#  97%|███████████████████████████████████████████████████████████████▏ | 5040300.0/5184000.0 [03:51<00:12, 11275.55it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   | ((np.isnan(pd["dt"])) & np.equal(time, pd["time"], where=np.isfinite(pd["time"])))
# 100%|█████████████████████████████████████████████████████████████████| 5184000.0/5184000.0 [04:03<00:00, 21329.79it/s]

# %% [markdown]
# ## Deep Atmosphere - Altitudes below 48 km

# %% [markdown]
# ### Latitude 0-40 - The Zonal Superrotating Jet

# %% [markdown]
# Latitude 0, Altitude 43km:

# %%
import xarray as xr
from heatmap import basic_heatmap, double_heatmap
from traj_stats import sum_ranges
ds = xr.open_zarr('outputs/lon90_lat0_alt43.zarr')
double_heatmap(ds)
sum_ranges(ds)
# Out:
# 0.0% of particles stayed in the latitude range.
# 100.0% of particles ended up outside the latitude range.
# 100.0% of particles stayed in the altitude range.
# 0.0% of particles ended up outside the altitude range.
# Mean final position: Latitude 5.353558540344238, altitude 42.310386657714844 km.
# Standard deviation on final position: Latitude 1.5867292881011963, altitude 0.5460193157196045 km.

# %% [markdown]
# Latitude 10, Altitude 43km:

# %%
import xarray as xr
from heatmap import basic_heatmap, double_heatmap
from traj_stats import sum_ranges
ds = xr.open_zarr('outputs/lon90_lat10_alt43.zarr')
double_heatmap(ds)
sum_ranges(ds)
# Out:
# 99 particles stayed in the latitude range.
# 1 particles ended up outside the latitude range.
# 96 particles stayed in the altitude range.
# 4 particles ended up outside the altitude range.

# %% [markdown]
# Latitude 20, Altitude 43km:

# %%
import xarray as xr
from heatmap import double_heatmap
from traj_stats import sum_ranges
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)
sum_ranges(ds)
# Out:
# 100 particles stayed in the latitude range.
# 0 particles ended up outside the latitude range.
# 97 particles stayed in the altitude range.
# 3 particles ended up outside the altitude range.

# %% [markdown]
# Latitude 30, Altitude 43km:

# %%
import xarray as xr
from heatmap import basic_heatmap, double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)

# %% [markdown]
# ### Latitude 40-60 - Edge of the Superrotating Jet

# %% [markdown]
# Latitude 40, Altitude 43km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# Latitude 50, Altitude 43km:

# %%
import xarray as xr
from heatmap import double_heatmap
from traj_stats import sum_ranges, means
ds = xr.open_zarr('outputs/lon90_lat50_alt43.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot
sum_ranges(ds)
means(ds)
# Out:
# 74.0% of particles stayed in the latitude range.
# 26.0% of particles ended up outside the latitude range.
# 100.0% of particles stayed in the altitude range.
# 0.0% of particles ended up outside the altitude range.
# Mean final position: Latitude 53.3921012878418 degrees, altitude 43.08143997192383 km.
# Standard deviation on final position: Latitude 10.356093406677246 degrees, altitude 2.002768039703369 km.
#
# Mean values:
# Trajectory: 1, Mean Latitude: 57.23175811767578 degrees, Mean Altitude: 42.108436584472656 km.
# Trajectory: 2, Mean Latitude: 59.79315185546875 degrees, Mean Altitude: 43.34053421020508 km.
# Trajectory: 3, Mean Latitude: 54.02526092529297 degrees, Mean Altitude: 42.61894989013672 km.
# Trajectory: 4, Mean Latitude: 52.79059600830078 degrees, Mean Altitude: 43.06523513793945 km.
# Trajectory: 5, Mean Latitude: 53.41938400268555 degrees, Mean Altitude: 43.21282958984375 km.
# Trajectory: 6, Mean Latitude: 59.64310073852539 degrees, Mean Altitude: 44.094818115234375 km.
# Trajectory: 7, Mean Latitude: 54.482398986816406 degrees, Mean Altitude: 42.599266052246094 km.
# Trajectory: 8, Mean Latitude: 51.35926055908203 degrees, Mean Altitude: 43.60736083984375 km.
# Trajectory: 9, Mean Latitude: 62.227195739746094 degrees, Mean Altitude: 42.22869873046875 km.
# Trajectory: 10, Mean Latitude: 59.197853088378906 degrees, Mean Altitude: 42.53570556640625 km.
# Trajectory: 11, Mean Latitude: 54.50630569458008 degrees, Mean Altitude: 42.95089340209961 km.
# Trajectory: 12, Mean Latitude: 51.918251037597656 degrees, Mean Altitude: 43.979713439941406 km.
# Trajectory: 13, Mean Latitude: 53.354618072509766 degrees, Mean Altitude: 43.31024169921875 km.
# Trajectory: 14, Mean Latitude: 55.094234466552734 degrees, Mean Altitude: 43.12040328979492 km.
# Trajectory: 78, Latitude: 5.470335483551025 degrees, Altitude: 0.5136565566062927 km.
# Trajectory: 79, Latitude: 7.003835201263428 degrees, Altitude: 1.5889071226119995 km.
# Trajectory: 80, Latitude: 5.665370464324951 degrees, Altitude: 0.740409791469574 km.
# Trajectory: 81, Latitude: 6.9298415184021 degrees, Altitude: 0.31567782163619995 km.
# Trajectory: 82, Latitude: 7.520995140075684 degrees, Altitude: 0.7142823338508606 km.
# Trajectory: 83, Latitude: 7.221684455871582 degrees, Altitude: 1.3183979988098145 km.
# Trajectory: 84, Latitude: 8.173930168151855 degrees, Altitude: 0.4522964656352997 km.
# Trajectory: 85, Latitude: 6.556807518005371 degrees, Altitude: 0.9317501187324524 km.
# Trajectory: 86, Latitude: 7.537444114685059 degrees, Altitude: 0.9295104742050171 km.
# Trajectory: 87, Latitude: 6.196238040924072 degrees, Altitude: 0.719474732875824 km.
# Trajectory: 88, Latitude: 7.11550760269165 degrees, Altitude: 0.4856474995613098 km.
# Trajectory: 89, Latitude: 5.709287166595459 degrees, Altitude: 0.5676427483558655 km.
# Trajectory: 90, Latitude: 6.3030104637146 degrees, Altitude: 0.5949360728263855 km.
# Trajectory: 91, Latitude: 5.847466945648193 degrees, Altitude: 0.5445994138717651 km.
# Trajectory: 92, Latitude: 8.684320449829102 degrees, Altitude: 0.6635372638702393 km.
# Trajectory: 93, Latitude: 6.912703037261963 degrees, Altitude: 0.780307948589325 km.
# Trajectory: 94, Latitude: 8.68589973449707 degrees, Altitude: 0.7322916388511658 km.
# Trajectory: 95, Latitude: 6.7349853515625 degrees, Altitude: 1.2719420194625854 km.
# Trajectory: 96, Latitude: 9.275284767150879 degrees, Altitude: 0.5954307317733765 km.
# Trajectory: 97, Latitude: 6.369536876678467 degrees, Altitude: 1.2433078289031982 km.
# Trajectory: 98, Latitude: 5.4278154373168945 degrees, Altitude: 0.5696350932121277 km.
# Trajectory: 99, Latitude: 7.139251708984375 degrees, Altitude: 0.46454575657844543 km.
# Trajectory: 100, Latitude: 6.681352138519287 degrees, Altitude: 0.7860258221626282 km.

# %% [markdown]
# Latitude 60, Altitude 43km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# ### Latitude 60-90 - Poles

# %% [markdown]
# Latitude 70, Altitude 43km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# Latitude 80, Altitude 43km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# ## Convective Cloud Deck - Altitudes 48-55 km

# %% [markdown]
# ### Latitude 0-40 - The Zonal Superrotating Jet

# %% [markdown]
# Latitude 0 (Equator), 51km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# Latitude 10, 51km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# Latitude 20, 51km:

# %%
import xarray as xr
from heatmap import double_heatmap
from traj_stats import sum_ranges, means
ds = xr.open_zarr('outputs/lon90_lat20_alt51.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot
sum_ranges(ds)
means(ds)
# Out:
# 54.0% of particles stayed in the latitude range.
# 46.0% of particles ended up outside the latitude range.
# 4.0% of particles stayed in the altitude range.
# 96.0% of particles ended up outside the altitude range.
# Mean final position: Latitude 38.80131530761719 degrees, altitude 47.13706970214844 km.
# Standard deviation on final position: Latitude 17.81953239440918 degrees, altitude 4.71932315826416 km.
#
# Mean values:
# Trajectory: 1, Mean Latitude: 41.30908966064453 degrees, Mean Altitude: 56.81415939331055 km.
# Trajectory: 2, Mean Latitude: 15.8396577835083 degrees, Mean Altitude: 45.54220962524414 km.
51km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# ### Latitude 40-60: Edge of Superrotating Jet

# %% [markdown]
# Latitude 40, Altitude 51km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# Latitude 50, Altitude 51km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# Latitude 60, 51km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# ### Latitude 60-90: Poles

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# ## The Upper Cloud Deck - Altitudes 55 km+

# %% [markdown]
# ### Latitude 0-40: The Zonal Superrotating Jet

# %% [markdown]
# Latitude 0 (Equator), Altitude 60km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# Latitude 0, Altitude 63km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# Latitude 10, Altitude 60km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# Latitude 20, Altitude 60km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# Latitude 30, Altitude 60km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# ### Latitude 40-60: Edge of the Superrotating Jet

# %% [markdown]
# Latitude 40, Altitude 60km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# Latitude 50, Altitude 60km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# Altitude 60, 60km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %% [markdown]
# ### Latitude 60-90: Poles

# %% [markdown]
# Latitude 80, Altitude 60km:

# %%
import xarray as xr
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot

# %%
import xarray as xr
from heatmap import double_heatmap
from traj_statistics import sum_in_bounds
ds = xr.open_zarr('outputs/Test2.zarr')
double_heatmap(ds)          # all trajectories on one 2-D plot
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       2 from heatmap import double_heatmap
#       3 from traj_statistics import sum_in_bounds
#       4 ds = xr.open_zarr('outputs/Test2.zarr')
#       5 double_heatmap(ds)          # all trajectories on one 2-D plot
# ----> 6 sum_in_bounds(ds)
#
# File ~/latraj/traj_statistics.py:15, in sum_in_bounds(ds)
#      13 lon_raw = traj.lon.values
#      14 lat_raw = traj.lat.values
# ---> 15 z_raw = traj.z.values/1000
#      17 # how to determine boundaries for different simulations? manually? is there an automatic way?
#      18 if lat_raw[-1] > 40 or lat_raw[-1] < -40:
#
# File ~/miniconda3/envs/parcels/lib/python3.13/site-packages/xarray/core/dataarray.py:803, in DataArray.values(self)
#     790 @property
#     791 def values(self) -> np.ndarray:
#     792     """
#     793     The array's data converted to numpy.ndarray.
#     794
#    (...)    801     to this array may be reflected in the DataArray as well.
#     802     """
# --> 803     return self.variable.values
#
# File ~/miniconda3/envs/parcels/lib/python3.13/site-packages/xarray/core/variable.py:555, in Variable.values(self)
#     552 @property
#     553 def values(self) -> np.ndarray:
#     554     """The variable's data as a numpy.ndarray"""
# --> 555     return _as_array_or_item(self._data)
#
# File ~/miniconda3/envs/parcels/lib/python3.13/site-packages/xarray/core/variable.py:335, in _as_array_or_item(data)
#     321 def _as_array_or_item(data):
#     322     """Return the given values as a numpy array, or as an individual item if
#     323     it's a 0d datetime64 or timedelta64 array.
#     324
#    (...)    333     TODO: remove this (replace with np.asarray) once these issues are fixed
#     334     """
# --> 335     data = np.asarray(data)
#     336     if data.ndim == 0:
#     337         kind = data.dtype.kind
#
# File ~/miniconda3/envs/parcels/lib/python3.13/site-packages/dask/array/core.py:1724, in Array.__array__(self, dtype, copy, **kwargs)
#    1717 if copy is False:
#    1718     warnings.warn(
#    1719         "Can't acquire a memory view of a Dask array. "
#    1720         "This will raise in the future.",
#    1721         FutureWarning,
#    1722     )
# -> 1724 x = self.compute()
#    1726 # Apply requested dtype and convert non-numpy backends to numpy.
#    1727 # If copy is True, numpy is going to perform its own deep copy
#    1728 # after this method returns.
#    1729 # If copy is None, finalize() ensures that the returned object
#    1730 # does not share memory with an object stored in the graph or on a
#    1731 # process-local Worker.
#    1732 return np.asarray(x, dtype=dtype)
#
# File ~/miniconda3/envs/parcels/lib/python3.13/site-packages/dask/base.py:373, in DaskMethodsMixin.compute(self, **kwargs)
#     349 def compute(self, **kwargs):
#     350     """Compute this dask collection
#     351
#     352     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)    371     dask.compute
#     372     """
# --> 373     (result,) = compute(self, traverse=False, **kwargs)
#     374     return result
#
# File ~/miniconda3/envs/parcels/lib/python3.13/site-packages/dask/base.py:681, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     678     expr = expr.optimize()
#     679     keys = list(flatten(expr.__dask_keys__()))
# --> 681     results = schedule(expr, keys, **kwargs)
#     683 return repack(results)
#
# File ~/miniconda3/envs/parcels/lib/python3.13/queue.py:199, in Queue.get(self, block, timeout)
#     197 elif timeout is None:
#     198     while not self._qsize():
# --> 199         self.not_empty.wait()
#     200         if self.is_shutdown and not self._qsize():
#     201             raise ShutDown
#
# File ~/miniconda3/envs/parcels/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     357 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     358     if timeout is None:
# --> 359         waiter.acquire()
#     360         gotit = True
#     361     else:
#
# KeyboardInterrupt:
