# %%
import importlib, config, custom_kernels, visualisations
importlib.reload(config)
importlib.reload(custom_kernels)
importlib.reload(visualisations)
# Out:
# <module 'visualisations' from '/home/paul/repos/latraj/visualisations.py'>

# %%
# %run run_venus_simulation.py
# Out:
# ['inputs//XinsTest.nc']
# INFO: Output files are stored in outputs/Test.zarr.
#   0%|                                            | 0/5184000.0 [00:00<?, ?it/s]
# /home/paul/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/paul/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/paul/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
# ...

# %%
import xarray as xr
from visualisations import doubletraj, traj3d
ds = xr.open_zarr('outputs/Test.zarr')
doubletraj(ds)          # all trajectories on one 3-D plot

# %%
import xarray as xr
from visualisations import traj3d
ds = xr.open_zarr('outputs/Test.zarr')
traj3d(ds, 3)
