# %% [markdown]
# # Venus Trajectory Simulator

# %% [markdown]
# ### How to use:
# * Enter your desired intial positions into config.py.
# * Give your output file a different name for each run.
# * Run the Venus trajectory simulation.
# * Run your output file in the "Venus Trajectory Analysis" notebook.

# %%
# Reload kernels
import importlib
import parcels
import config
import custom_kernels
importlib.reload(config)
importlib.reload(custom_kernels)
# Out:
# <module 'custom_kernels' from '/home/tpj37/latraj/custom_kernels.py'>

# %%
# %run run_venus_simulation.py
# Out:
# ['inputs//AerobotRun_corr.nc']
# INFO: Output files are stored in outputs/KernelTest.zarr.
#
#
#
#
#
#   0%|                                                                     | 300.0/1728000.0 [00:52<84:15:36,  5.70it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/field.py:1142: RuntimeWarning: Sampling of velocities should normally be done using fieldset.UV or fieldset.UVW object; tread carefully
#   self._check_velocitysampling()
# <ast>:23: RuntimeWarning: overflow encountered in scalar multiply
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File ~/latraj/run_venus_simulation.py:136
#     134 # %%
#     135 if __name__ == "__main__":
# --> 136     main()
#
# File ~/latraj/run_venus_simulation.py:126, in main()
#     121 output_file = pset_clouds.ParticleFile(
#     122               name=savedir + config.OUTPUT_NAME,
#     123               outputdt=timedelta(minutes=config.OUTPUT_MINUTES),
#     124 )
#     125 #pset_clouds.execute([AdvectionRK4, balloon_vertical, smagdiff, periodicBC, boundary_stick],
# --> 126 pset_clouds.execute([balloon_vertical],
#     127              runtime=timedelta(days=config.RUNTIME_DAYS),
#     128              dt=timedelta(minutes=config.DT_MINUTES),
#     129              output_file=output_file,
#     130              verbose_progress=True,
#     131 )
#
# File ~/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particleset.py:1180, in ParticleSet.execute(self, pyfunc, pyfunc_inter, endtime, runtime, dt, output_file, verbose_progress, postIterationCallbacks, callbackdt, delete_cfiles)
#    1178 if self._interaction_kernel is None:
#    1179     if not skip_kernel:
# -> 1180         res = self._kernel.execute(self, endtime=next_time, dt=dt)
#    1181         if res == StatusCode.StopAllExecution:
#    1182             return StatusCode.StopAllExecution
#
# File ~/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/kernel.py:630, in Kernel.execute(self, pset, endtime, dt)
#     628     self.execute_jit(pset, endtime, dt)
#     629 else:
# --> 630     self.execute_python(pset, endtime, dt)
#     632 # Remove all particles that signalled deletion
#     633 self.remove_deleted(pset)
#
# File ~/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/kernel.py:604, in Kernel.execute_python(self, pset, endtime, dt)
#     601     self.scipy_positionupdate_kernels_added = True
#     603 for p in pset:
# --> 604     self.evaluate_particle(p, endtime)
#     605     if p.state == StatusCode.StopAllExecution:
#     606         return StatusCode.StopAllExecution
#
# File ~/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/kernel.py:702, in Kernel.evaluate_particle(self, p, endtime)
#     700     if abs(endtime - p.time_nextloop) < abs(p.dt) - 1e-6:
#     701         p.dt = abs(endtime - p.time_nextloop) * sign_dt
# --> 702 res = self._pyfunc(p, self._fieldset, p.time_nextloop)
#     704 if res is None:
#     705     if sign_dt * p.time < sign_dt * endtime and p.state == StatusCode.Success:
#
# File <ast>:25, in Setcoordsballoon_verticalUpdatecoords(particle, fieldset, time)
#
# OverflowError: math range error

# %%
from heatmap import double_heatmap
ds = xr.open_zarr('outputs/KernelTest.zarr')
double_heatmap(ds)
ds.lat.values
# Out:
# array([[30., nan, nan, ..., nan, nan, nan],
#        [30., nan, nan, ..., nan, nan, nan],
#        [30., nan, nan, ..., nan, nan, nan],
#        ...,
#        [30., nan, nan, ..., nan, nan, nan],
#        [30., nan, nan, ..., nan, nan, nan],
#        [30., nan, nan, ..., nan, nan, nan]],
#       shape=(100, 960), dtype=float32)
