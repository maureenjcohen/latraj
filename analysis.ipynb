# %% [markdown]
# # Venus Trajectory Simulations

# %%
import importlib
import config
import custom_kernels
import visualisations
import heatmap
import parcels
importlib.reload(config)
importlib.reload(custom_kernels)
importlib.reload(visualisations)
importlib.reload(heatmap)
# Out:
# <module 'heatmap' from '/home/tpj37/latraj/heatmap.py'>

# %% [markdown]
# ## Deep Atmosphere - Altitudes below 48 km

# %% [markdown]
# ### Latitude 0-40 - Zonal Superrotating Jet

# %%
# %run run_venus_simulation.py
# Out:
# ['inputs//XinsTest.nc']
# INFO: Output files are stored in outputs/Test2.zarr.
#   0%|                                                                                    | 0/5184000.0 [00:00<?, ?it/s]
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# /home/tpj37/miniconda3/envs/parcels/lib/python3.13/site-packages/parcels/particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# ...

# %%
import xarray as xr
from heatmap import basic_heatmap, double_heatmap
from visualisations import traj3d
ds = xr.open_zarr('outputs/Test2.zarr')
#ds
basic_heatmap(ds)
traj3d(ds, 212)

# %% [markdown]
# ### Latitude 40-60 - Edge of the Superrotating Jet

# %%
# %run run_venus_simulation.py
# Out:
# ['inputs/XinsTest.nc']
# INFO: Output files are stored in outputs/Test2.zarr.
#   0%|          | 0/5184000.0 [00:00<?, ?it/s]
# C:\Users\tpj37\AppData\Local\miniconda3\envs\parcels\Lib\site-packages\parcels\particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# C:\Users\tpj37\AppData\Local\miniconda3\envs\parcels\Lib\site-packages\parcels\particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# C:\Users\tpj37\AppData\Local\miniconda3\envs\parcels\Lib\site-packages\parcels\particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
# ...

# %%
import xarray as xr
from visualisations import doubletraj
ds = xr.open_zarr('outputs/Test2.zarr')
doubletraj(ds)          # all trajectories on one 3-D plot

# %% [markdown]
# ### Latitude 60-90 - Poles

# %%
# %run run_venus_simulation.py
# Out:
# ['inputs/XinsTest.nc']
# INFO: Output files are stored in outputs/Test2.zarr.
#   0%|          | 0/5184000.0 [00:00<?, ?it/s]
# C:\Users\tpj37\AppData\Local\miniconda3\envs\parcels\Lib\site-packages\parcels\particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# C:\Users\tpj37\AppData\Local\miniconda3\envs\parcels\Lib\site-packages\parcels\particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# C:\Users\tpj37\AppData\Local\miniconda3\envs\parcels\Lib\site-packages\parcels\particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
# ...

# %%
import xarray as xr
from visualisations import doubletraj
ds = xr.open_zarr('outputs/Test2.zarr')
doubletraj(ds)          # all trajectories on one 3-D plot

# %% [markdown]
# ## Convective Cloud Deck - Altitudes 48-55 km

# %% [markdown]
# ### Latitude 0-40 - Zonal Superrotating Jet

# %%
# %run run_venus_simulation.py
# Out:
# ['inputs/XinsTest.nc']
# INFO: Output files are stored in outputs/Test2.zarr.
#   0%|          | 1800.0/5184000.0 [00:00<05:22, 16068.08it/s]
# C:\Users\tpj37\AppData\Local\miniconda3\envs\parcels\Lib\site-packages\parcels\particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# C:\Users\tpj37\AppData\Local\miniconda3\envs\parcels\Lib\site-packages\parcels\particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# C:\Users\tpj37\AppData\Local\miniconda3\envs\parcels\Lib\site-packages\parcels\particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
# ...

# %%
import xarray as xr
from visualisations import doubletraj
ds = xr.open_zarr('outputs/Test2.zarr')
doubletraj(ds)          # all trajectories on one 3-D plot

# %% [markdown]
# ### Latitude 40-60: Edge of Superrotating Jet

# %%
# %run run_venus_simulation.py
# Out:
# ['inputs/XinsTest.nc']
# INFO: Output files are stored in outputs/Test2.zarr.
#   0%|          | 1800.0/5184000.0 [00:00<04:56, 17452.59it/s]
# C:\Users\tpj37\AppData\Local\miniconda3\envs\parcels\Lib\site-packages\parcels\particledata.py:358: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   np.less_equal(time - np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# C:\Users\tpj37\AppData\Local\miniconda3\envs\parcels\Lib\site-packages\parcels\particledata.py:359: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
#   & np.greater_equal(time + np.abs(pd["dt"] / 2), pd["time"], where=np.isfinite(pd["time"]))
# C:\Users\tpj37\AppData\Local\miniconda3\envs\parcels\Lib\site-packages\parcels\particledata.py:360: UserWarning: 'where' used without 'out', expect uninitialized memory in output. If this is intentional, use out=None.
# ...

# %%
import xarray as xr
from visualisations import doubletraj
ds = xr.open_zarr('outputs/Test2.zarr')
doubletraj(ds)          # all trajectories on one 3-D plot
